# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create DataFrame
data = {
    'Approach': ['N_Grams', 'N_Grams', 'Bag of Words', 'Bag of Words', 'Cosine Similarity', 'Cosine Similarity'],
    'Model': ['Support Vector Classifier', 'Logistic Regression', 'Logistic Regression', 'Support Vector Classifier', 'Neural Network', 'Logistic Regression'],
    'Accuracy': [100, 100, 99.0, 100, 100, 98.7],
    'Type': ['Train', 'Test', 'Train', 'Test', 'Train', 'Test']
}

df = pd.DataFrame(data)

# Set style
sns.set(style="whitegrid")

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(x="Approach", y="Accuracy", hue="Type", data=df, palette="Set3", ci=None)
plt.title('Train and Test Accuracies by Model and Approach')
plt.xlabel('Approach')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.legend(title='Model')
plt.show()
# Out:
# C:\Users\Vinay\AppData\Local\Temp\ipykernel_11248\1239069545.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Approach", y="Accuracy", hue="Type", data=df, palette="Set3", ci=None)
